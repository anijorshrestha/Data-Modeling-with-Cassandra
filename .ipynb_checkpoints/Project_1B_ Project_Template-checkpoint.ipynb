# %% [markdown]
# # Part I. ETL Pipeline for Pre-Processing the Files

# %% [markdown]
# ## PLEASE RUN THE FOLLOWING CODE FOR PRE-PROCESSING THE FILES

# %% [markdown]
# #### Import Python packages

# %%
# Import Python packages 
import pandas as pd
import cassandra
import re
import os
import glob
import numpy as np
import json
import csv

# %%
# !pip3 install cassandra-driver
# Out:
# Collecting cassandra-driver
#   Downloading cassandra-driver-3.25.0.tar.gz (289 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.0/290.0 KB 3.4 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: six>=1.9 in /Users/rojinashrestha/miniforge3/envs/mlp/lib/python3.8/site-packages (from cassandra-driver) (1.15.0)
# Collecting geomet<0.3,>=0.1
#   Downloading geomet-0.2.1.post1-py3-none-any.whl (18 kB)
# Collecting click
#   Downloading click-8.1.3-py3-none-any.whl (96 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.6/96.6 KB 2.2 MB/s eta 0:00:00a 0:00:01
# Building wheels for collected packages: cassandra-driver
#   Building wheel for cassandra-driver (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [2687 lines of output]
#       /Users/rojinashrestha/miniforge3/envs/mlp/lib/python3.8/site-packages/setuptools/installer.py:27: SetuptoolsDeprecationWarning: setuptools.installer is deprecated. Requirements should be satisfied by a PEP 517 installer.
#         warnings.warn(
#       running bdist_wheel
#       running build
#       running build_py
#       creating build
#       creating build/lib.macosx-11.0-arm64-cpython-38
#       creating build/lib.macosx-11.0-arm64-cpython-38/cassandra
#       copying cassandra/marshal.py -> build/lib.macosx-11.0-arm64-cpython-38/cassandra
#       copying cassandra/auth.py -> build/lib.macosx-11.0-arm64-cpython-38/cassandra
#       copying cassandra/metrics.py -> build/lib.macosx-11.0-arm64-cpython-38/cassandra
#       copying cassandra/concurrent.py -> build/lib.macosx-11.0-arm64-cpython-38/cassandra
#       copying cassandra/metadata.py -> build/lib.macosx-11.0-arm64-cpython-38/cassandra
#       copying cassandra/compat.py -> build/lib.macosx-11.0-arm64-cpython-38/cassandra
#       copying cassandra/query.py -> build/lib.macosx-11.0-arm64-cpython-38/cassandra
#       copying cassandra/util.py -> build/lib.macosx-11.0-arm64-cpython-38/cassandra
#       copying cassandra/timestamps.py -> build/lib.macosx-11.0-arm64-cpython-38/cassandra
#       copying cassandra/cqltypes.py -> build/lib.macosx-11.0-arm64-cpython-38/cassandra
#       copying cassandra/protocol.py -> build/lib.macosx-11.0-arm64-cpython-38/cassandra
#       copying cassandra/__init__.py -> build/lib.macosx-11.0-arm64-cpython-38/cassandra
#       copying cassandra/murmur3.py -> build/lib.macosx-11.0-arm64-cpython-38/cassandra
#       copying cassandra/encoder.py -> build/lib.macosx-11.0-arm64-cpython-38/cassandra
#       copying cassandra/connection.py -> build/lib.macosx-11.0-arm64-cpython-38/cassandra
#       copying cassandra/cluster.py -> build/lib.macosx-11.0-arm64-cpython-38/cassandra
#       copying cassandra/cython_deps.py -> build/lib.macosx-11.0-arm64-cpython-38/cassandra
#       copying cassandra/type_codes.py -> build/lib.macosx-11.0-arm64-cpython-38/cassandra
#       copying cassandra/segment.py -> build/lib.macosx-11.0-arm64-cpython-38/cassandra
#       copying cassandra/pool.py -> build/lib.macosx-11.0-arm64-cpython-38/cassandra
#       copying cassandra/policies.py -> build/lib.macosx-11.0-arm64-cpython-38/cassandra
#       creating build/lib.macosx-11.0-arm64-cpython-38/cassandra/io
#       copying cassandra/io/asyncorereactor.py -> build/lib.macosx-11.0-arm64-cpython-38/cassandra/io
#       copying cassandra/io/asyncioreactor.py -> build/lib.macosx-11.0-arm64-cpython-38/cassandra/io
#       copying cassandra/io/twistedreactor.py -> build/lib.macosx-11.0-arm64-cpython-38/cassandra/io
#       copying cassandra/io/__init__.py -> build/lib.macosx-11.0-arm64-cpython-38/cassandra/io
#       copying cassandra/io/geventreactor.py -> build/lib.macosx-11.0-arm64-cpython-38/cassandra/io
#       copying cassandra/io/libevreactor.py -> build/lib.macosx-11.0-arm64-cpython-38/cassandra/io
#       copying cassandra/io/eventletreactor.py -> build/lib.macosx-11.0-arm64-cpython-38/cassandra/io
#       creating build/lib.macosx-11.0-arm64-cpython-38/cassandra/cqlengine
#       copying cassandra/cqlengine/functions.py -> build/lib.macosx-11.0-arm64-cpython-38/cassandra/cqlengine
#       copying cassandra/cqlengine/usertype.py -> build/lib.macosx-11.0-arm64-cpython-38/cassandra/cqlengine
#       copying cassandra/cqlengine/models.py -> build/lib.macosx-11.0-arm64-cpython-38/cassandra/cqlengine
#       copying cassandra/cqlengine/query.py -> build/lib.macosx-11.0-arm64-cpython-38/cassandra/cqlengine
#       copying cassandra/cqlengine/__init__.py -> build/lib.macosx-11.0-arm64-cpython-38/cassandra/cqlengine
#       copying cassandra/cqlengine/columns.py -> build/lib.macosx-11.0-arm64-cpython-38/cassandra/cqlengine
#       copying cassandra/cqlengine/connection.py -> build/lib.macosx-11.0-arm64-cpython-38/cassandra/cqlengine
#       copying cassandra/cqlengine/management.py -> build/lib.macosx-11.0-arm64-cpython-38/cassandra/cqlengine
#       copying cassandra/cqlengine/statements.py -> build/lib.macosx-11.0-arm64-cpython-38/cassandra/cqlengine
#       copying cassandra/cqlengine/operators.py -> build/lib.macosx-11.0-arm64-cpython-38/cassandra/cqlengine
#       copying cassandra/cqlengine/named.py -> build/lib.macosx-11.0-arm64-cpython-38/cassandra/cqlengine
#       creating build/lib.macosx-11.0-arm64-cpython-38/cassandra/graph
#       copying cassandra/graph/query.py -> build/lib.macosx-11.0-arm64-cpython-38/cassandra/graph
#       copying cassandra/graph/graphson.py -> build/lib.macosx-11.0-arm64-cpython-38/cassandra/graph
#       copying cassandra/graph/__init__.py -> build/lib.macosx-11.0-arm64-cpython-38/cassandra/graph
#       copying cassandra/graph/types.py -> build/lib.macosx-11.0-arm64-cpython-38/cassandra/graph
#       creating build/lib.macosx-11.0-arm64-cpython-38/cassandra/datastax
#       copying cassandra/datastax/__init__.py -> build/lib.macosx-11.0-arm64-cpython-38/cassandra/datastax
#       creating build/lib.macosx-11.0-arm64-cpython-38/cassandra/datastax/insights
#       copying cassandra/datastax/insights/registry.py -> build/lib.macosx-11.0-arm64-cpython-38/cassandra/datastax/insights
#       copying cassandra/datastax/insights/util.py -> build/lib.macosx-11.0-arm64-cpython-38/cassandra/datastax/insights
#       copying cassandra/datastax/insights/serializers.py -> build/lib.macosx-11.0-arm64-cpython-38/cassandra/datastax/insights
#       copying cassandra/datastax/insights/reporter.py -> build/lib.macosx-11.0-arm64-cpython-38/cassandra/datastax/insights
#       copying cassandra/datastax/insights/__init__.py -> build/lib.macosx-11.0-arm64-cpython-38/cassandra/datastax/insights
#       creating build/lib.macosx-11.0-arm64-cpython-38/cassandra/datastax/graph
#       copying cassandra/datastax/graph/query.py -> build/lib.macosx-11.0-arm64-cpython-38/cassandra/datastax/graph
#       copying cassandra/datastax/graph/graphson.py -> build/lib.macosx-11.0-arm64-cpython-38/cassandra/datastax/graph
#       copying cassandra/datastax/graph/__init__.py -> build/lib.macosx-11.0-arm64-cpython-38/cassandra/datastax/graph
#       copying cassandra/datastax/graph/types.py -> build/lib.macosx-11.0-arm64-cpython-38/cassandra/datastax/graph
#       creating build/lib.macosx-11.0-arm64-cpython-38/cassandra/datastax/graph/fluent
#       copying cassandra/datastax/graph/fluent/predicates.py -> build/lib.macosx-11.0-arm64-cpython-38/cassandra/datastax/graph/fluent
#       copying cassandra/datastax/graph/fluent/query.py -> build/lib.macosx-11.0-arm64-cpython-38/cassandra/datastax/graph/fluent
#       copying cassandra/datastax/graph/fluent/_serializers.py -> build/lib.macosx-11.0-arm64-cpython-38/cassandra/datastax/graph/fluent
#       copying cassandra/datastax/graph/fluent/serializers.py -> build/lib.macosx-11.0-arm64-cpython-38/cassandra/datastax/graph/fluent
#       copying cassandra/datastax/graph/fluent/_query.py -> build/lib.macosx-11.0-arm64-cpython-38/cassandra/datastax/graph/fluent
#       copying cassandra/datastax/graph/fluent/__init__.py -> build/lib.macosx-11.0-arm64-cpython-38/cassandra/datastax/graph/fluent
#       copying cassandra/datastax/graph/fluent/_predicates.py -> build/lib.macosx-11.0-arm64-cpython-38/cassandra/datastax/graph/fluent
#       creating build/lib.macosx-11.0-arm64-cpython-38/cassandra/datastax/cloud
#       copying cassandra/datastax/cloud/__init__.py -> build/lib.macosx-11.0-arm64-cpython-38/cassandra/datastax/cloud
#       running egg_info
#       writing cassandra_driver.egg-info/PKG-INFO
#       writing dependency_links to cassandra_driver.egg-info/dependency_links.txt
#       writing requirements to cassandra_driver.egg-info/requires.txt
#       writing top-level names to cassandra_driver.egg-info/top_level.txt
#       reading manifest file 'cassandra_driver.egg-info/SOURCES.txt'
#       reading manifest template 'MANIFEST.in'
#       adding license file 'LICENSE'
#       writing manifest file 'cassandra_driver.egg-info/SOURCES.txt'
#       copying cassandra/buffer.pxd -> build/lib.macosx-11.0-arm64-cpython-38/cassandra
#       copying cassandra/bytesio.pxd -> build/lib.macosx-11.0-arm64-cpython-38/cassandra
#       copying cassandra/bytesio.pyx -> build/lib.macosx-11.0-arm64-cpython-38/cassandra
#       copying cassandra/cmurmur3.c -> build/lib.macosx-11.0-arm64-cpython-38/cassandra
#       copying cassandra/cython_marshal.pyx -> build/lib.macosx-11.0-arm64-cpython-38/cassandra
#       copying cassandra/cython_utils.pxd -> build/lib.macosx-11.0-arm64-cpython-38/cassandra
#       copying cassandra/cython_utils.pyx -> build/lib.macosx-11.0-arm64-cpython-38/cassandra
#       copying cassandra/deserializers.pxd -> build/lib.macosx-11.0-arm64-cpython-38/cassandra
#       copying cassandra/deserializers.pyx -> build/lib.macosx-11.0-arm64-cpython-38/cassandra
#       copying cassandra/ioutils.pyx -> build/lib.macosx-11.0-arm64-cpython-38/cassandra
#       copying cassandra/numpyFlags.h -> build/lib.macosx-11.0-arm64-cpython-38/cassandra
#       copying cassandra/numpy_parser.pyx -> build/lib.macosx-11.0-arm64-cpython-38/cassandra
#       copying cassandra/obj_parser.pyx -> build/lib.macosx-11.0-arm64-cpython-38/cassandra
#       copying cassandra/parsing.pxd -> build/lib.macosx-11.0-arm64-cpython-38/cassandra
#       copying cassandra/parsing.pyx -> build/lib.macosx-11.0-arm64-cpython-38/cassandra
#       copying cassandra/row_parser.pyx -> build/lib.macosx-11.0-arm64-cpython-38/cassandra
#       copying cassandra/tuple.pxd -> build/lib.macosx-11.0-arm64-cpython-38/cassandra
#       copying cassandra/type_codes.pxd -> build/lib.macosx-11.0-arm64-cpython-38/cassandra
#       copying cassandra/io/libevwrapper.c -> build/lib.macosx-11.0-arm64-cpython-38/cassandra/io
#       running build_ext
#       Compiling cassandra/cluster.py because it changed.
#       Compiling cassandra/concurrent.py because it changed.
#       Compiling cassandra/connection.py because it changed.
#       Compiling cassandra/cqltypes.py because it changed.
#       Compiling cassandra/metadata.py because it changed.
#       Compiling cassandra/pool.py because it changed.
#       Compiling cassandra/protocol.py because it changed.
#       Compiling cassandra/query.py because it changed.
#       Compiling cassandra/util.py because it changed.
#       [1/9] Cythonizing cassandra/cluster.py
#       /private/var/folders/sn/b8252hqj551fq4386bsnpn800000gn/T/pip-install-wt2gnbyu/cassandra-driver_a670d6ab7456443787c88025d42dad38/.eggs/Cython-0.29.31-py3.8.egg/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /private/var/folders/sn/b8252hqj551fq4386bsnpn800000gn/T/pip-install-wt2gnbyu/cassandra-driver_a670d6ab7456443787c88025d42dad38/cassandra/cluster.py
#         tree = Parsing.p_module(s, pxd, full_module_name)
#       [2/9] Cythonizing cassandra/concurrent.py
#       /private/var/folders/sn/b8252hqj551fq4386bsnpn800000gn/T/pip-install-wt2gnbyu/cassandra-driver_a670d6ab7456443787c88025d42dad38/.eggs/Cython-0.29.31-py3.8.egg/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /private/var/folders/sn/b8252hqj551fq4386bsnpn800000gn/T/pip-install-wt2gnbyu/cassandra-driver_a670d6ab7456443787c88025d42dad38/cassandra/concurrent.py
#         tree = Parsing.p_module(s, pxd, full_module_name)
#       [3/9] Cythonizing cassandra/connection.py
#       /private/var/folders/sn/b8252hqj551fq4386bsnpn800000gn/T/pip-install-wt2gnbyu/cassandra-driver_a670d6ab7456443787c88025d42dad38/.eggs/Cython-0.29.31-py3.8.egg/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /private/var/folders/sn/b8252hqj551fq4386bsnpn800000gn/T/pip-install-wt2gnbyu/cassandra-driver_a670d6ab7456443787c88025d42dad38/cassandra/connection.py
#         tree = Parsing.p_module(s, pxd, full_module_name)
#       [4/9] Cythonizing cassandra/cqltypes.py
#       /private/var/folders/sn/b8252hqj551fq4386bsnpn800000gn/T/pip-install-wt2gnbyu/cassandra-driver_a670d6ab7456443787c88025d42dad38/.eggs/Cython-0.29.31-py3.8.egg/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /private/var/folders/sn/b8252hqj551fq4386bsnpn800000gn/T/pip-install-wt2gnbyu/cassandra-driver_a670d6ab7456443787c88025d42dad38/cassandra/cqltypes.py
#         tree = Parsing.p_module(s, pxd, full_module_name)
#       [5/9] Cythonizing cassandra/metadata.py
#       /private/var/folders/sn/b8252hqj551fq4386bsnpn800000gn/T/pip-install-wt2gnbyu/cassandra-driver_a670d6ab7456443787c88025d42dad38/.eggs/Cython-0.29.31-py3.8.egg/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /private/var/folders/sn/b8252hqj551fq4386bsnpn800000gn/T/pip-install-wt2gnbyu/cassandra-driver_a670d6ab7456443787c88025d42dad38/cassandra/metadata.py
#         tree = Parsing.p_module(s, pxd, full_module_name)
#       [6/9] Cythonizing cassandra/pool.py
#       /private/var/folders/sn/b8252hqj551fq4386bsnpn800000gn/T/pip-install-wt2gnbyu/cassandra-driver_a670d6ab7456443787c88025d42dad38/.eggs/Cython-0.29.31-py3.8.egg/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /private/var/folders/sn/b8252hqj551fq4386bsnpn800000gn/T/pip-install-wt2gnbyu/cassandra-driver_a670d6ab7456443787c88025d42dad38/cassandra/pool.py
#         tree = Parsing.p_module(s, pxd, full_module_name)
#       [7/9] Cythonizing cassandra/protocol.py
#       /private/var/folders/sn/b8252hqj551fq4386bsnpn800000gn/T/pip-install-wt2gnbyu/cassandra-driver_a670d6ab7456443787c88025d42dad38/.eggs/Cython-0.29.31-py3.8.egg/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /private/var/folders/sn/b8252hqj551fq4386bsnpn800000gn/T/pip-install-wt2gnbyu/cassandra-driver_a670d6ab7456443787c88025d42dad38/cassandra/protocol.py
#         tree = Parsing.p_module(s, pxd, full_module_name)
#       [8/9] Cythonizing cassandra/query.py
#       /private/var/folders/sn/b8252hqj551fq4386bsnpn800000gn/T/pip-install-wt2gnbyu/cassandra-driver_a670d6ab7456443787c88025d42dad38/.eggs/Cython-0.29.31-py3.8.egg/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /private/var/folders/sn/b8252hqj551fq4386bsnpn800000gn/T/pip-install-wt2gnbyu/cassandra-driver_a670d6ab7456443787c88025d42dad38/cassandra/query.py
#         tree = Parsing.p_module(s, pxd, full_module_name)
#       [9/9] Cythonizing cassandra/util.py
#       /private/var/folders/sn/b8252hqj551fq4386bsnpn800000gn/T/pip-install-wt2gnbyu/cassandra-driver_a670d6ab7456443787c88025d42dad38/.eggs/Cython-0.29.31-py3.8.egg/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /private/var/folders/sn/b8252hqj551fq4386bsnpn800000gn/T/pip-install-wt2gnbyu/cassandra-driver_a670d6ab7456443787c88025d42dad38/cassandra/util.py
#         tree = Parsing.p_module(s, pxd, full_module_name)
#       Compiling cassandra/bytesio.pyx because it changed.
#       Compiling cassandra/cython_marshal.pyx because it changed.
#       Compiling cassandra/cython_utils.pyx because it changed.
#       Compiling cassandra/deserializers.pyx because it changed.
#       Compiling cassandra/ioutils.pyx because it changed.
#       Compiling cassandra/numpy_parser.pyx because it changed.
#       Compiling cassandra/obj_parser.pyx because it changed.
#       Compiling cassandra/parsing.pyx because it changed.
#       Compiling cassandra/row_parser.pyx because it changed.
#       [1/9] Cythonizing cassandra/bytesio.pyx
#       /private/var/folders/sn/b8252hqj551fq4386bsnpn800000gn/T/pip-install-wt2gnbyu/cassandra-driver_a670d6ab7456443787c88025d42dad38/.eggs/Cython-0.29.31-py3.8.egg/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /private/var/folders/sn/b8252hqj551fq4386bsnpn800000gn/T/pip-install-wt2gnbyu/cassandra-driver_a670d6ab7456443787c88025d42dad38/cassandra/bytesio.pxd
#         tree = Parsing.p_module(s, pxd, full_module_name)
#       [2/9] Cythonizing cassandra/cython_marshal.pyx
#       /private/var/folders/sn/b8252hqj551fq4386bsnpn800000gn/T/pip-install-wt2gnbyu/cassandra-driver_a670d6ab7456443787c88025d42dad38/.eggs/Cython-0.29.31-py3.8.egg/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /private/var/folders/sn/b8252hqj551fq4386bsnpn800000gn/T/pip-install-wt2gnbyu/cassandra-driver_a670d6ab7456443787c88025d42dad38/cassandra/cython_marshal.pyx
#         tree = Parsing.p_module(s, pxd, full_module_name)
#       [3/9] Cythonizing cassandra/cython_utils.pyx
#       /private/var/folders/sn/b8252hqj551fq4386bsnpn800000gn/T/pip-install-wt2gnbyu/cassandra-driver_a670d6ab7456443787c88025d42dad38/.eggs/Cython-0.29.31-py3.8.egg/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /private/var/folders/sn/b8252hqj551fq4386bsnpn800000gn/T/pip-install-wt2gnbyu/cassandra-driver_a670d6ab7456443787c88025d42dad38/cassandra/cython_utils.pxd
#         tree = Parsing.p_module(s, pxd, full_module_name)
#       [4/9] Cythonizing cassandra/deserializers.pyx
#       /private/var/folders/sn/b8252hqj551fq4386bsnpn800000gn/T/pip-install-wt2gnbyu/cassandra-driver_a670d6ab7456443787c88025d42dad38/.eggs/Cython-0.29.31-py3.8.egg/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /private/var/folders/sn/b8252hqj551fq4386bsnpn800000gn/T/pip-install-wt2gnbyu/cassandra-driver_a670d6ab7456443787c88025d42dad38/cassandra/deserializers.pxd
#         tree = Parsing.p_module(s, pxd, full_module_name)
#       [5/9] Cythonizing cassandra/ioutils.pyx
#       /private/var/folders/sn/b8252hqj551fq4386bsnpn800000gn/T/pip-install-wt2gnbyu/cassandra-driver_a670d6ab7456443787c88025d42dad38/.eggs/Cython-0.29.31-py3.8.egg/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /private/var/folders/sn/b8252hqj551fq4386bsnpn800000gn/T/pip-install-wt2gnbyu/cassandra-driver_a670d6ab7456443787c88025d42dad38/cassandra/ioutils.pyx
#         tree = Parsing.p_module(s, pxd, full_module_name)
#       [6/9] Cythonizing cassandra/numpy_parser.pyx
#       /private/var/folders/sn/b8252hqj551fq4386bsnpn800000gn/T/pip-install-wt2gnbyu/cassandra-driver_a670d6ab7456443787c88025d42dad38/.eggs/Cython-0.29.31-py3.8.egg/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /private/var/folders/sn/b8252hqj551fq4386bsnpn800000gn/T/pip-install-wt2gnbyu/cassandra-driver_a670d6ab7456443787c88025d42dad38/cassandra/numpy_parser.pyx
#         tree = Parsing.p_module(s, pxd, full_module_name)
#       [7/9] Cythonizing cassandra/obj_parser.pyx
#       /private/var/folders/sn/b8252hqj551fq4386bsnpn800000gn/T/pip-install-wt2gnbyu/cassandra-driver_a670d6ab7456443787c88025d42dad38/.eggs/Cython-0.29.31-py3.8.egg/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /private/var/folders/sn/b8252hqj551fq4386bsnpn800000gn/T/pip-install-wt2gnbyu/cassandra-driver_a670d6ab7456443787c88025d42dad38/cassandra/obj_parser.pyx
#         tree = Parsing.p_module(s, pxd, full_module_name)
#       [8/9] Cythonizing cassandra/parsing.pyx
#       /private/var/folders/sn/b8252hqj551fq4386bsnpn800000gn/T/pip-install-wt2gnbyu/cassandra-driver_a670d6ab7456443787c88025d42dad38/.eggs/Cython-0.29.31-py3.8.egg/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /private/var/folders/sn/b8252hqj551fq4386bsnpn800000gn/T/pip-install-wt2gnbyu/cassandra-driver_a670d6ab7456443787c88025d42dad38/cassandra/parsing.pxd
#         tree = Parsing.p_module(s, pxd, full_module_name)
#       [9/9] Cythonizing cassandra/row_parser.pyx
#       /private/var/folders/sn/b8252hqj551fq4386bsnpn800000gn/T/pip-install-wt2gnbyu/cassandra-driver_a670d6ab7456443787c88025d42dad38/.eggs/Cython-0.29.31-py3.8.egg/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /private/var/folders/sn/b8252hqj551fq4386bsnpn800000gn/T/pip-install-wt2gnbyu/cassandra-driver_a670d6ab7456443787c88025d42dad38/cassandra/row_parser.pyx
#         tree = Parsing.p_module(s, pxd, full_module_name)
#       building 'cassandra.cmurmur3' extension
#       creating build/temp.macosx-11.0-arm64-cpython-38
#       creating build/temp.macosx-11.0-arm64-cpython-38/cassandra
#       clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/rojinashrestha/miniforge3/envs/mlp/include -arch arm64 -fPIC -O2 -isystem /Users/rojinashrestha/miniforge3/envs/mlp/include -arch arm64 -I/Users/rojinashrestha/miniforge3/envs/mlp/include/python3.8 -c cassandra/cmurmur3.c -o build/temp.macosx-11.0-arm64-cpython-38/cassandra/cmurmur3.o
#       clang -bundle -undefined dynamic_lookup -Wl,-rpath,/Users/rojinashrestha/miniforge3/envs/mlp/lib -L/Users/rojinashrestha/miniforge3/envs/mlp/lib -Wl,-rpath,/Users/rojinashrestha/miniforge3/envs/mlp/lib -L/Users/rojinashrestha/miniforge3/envs/mlp/lib build/temp.macosx-11.0-arm64-cpython-38/cassandra/cmurmur3.o -o build/lib.macosx-11.0-arm64-cpython-38/cassandra/cmurmur3.cpython-38-darwin.so
#       building 'cassandra.io.libevwrapper' extension
#       creating build/temp.macosx-11.0-arm64-cpython-38/cassandra/io
#       clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/rojinashrestha/miniforge3/envs/mlp/include -arch arm64 -fPIC -O2 -isystem /Users/rojinashrestha/miniforge3/envs/mlp/include -arch arm64 -I/usr/include/libev -I/usr/local/include -I/opt/local/include -I/Users/rojinashrestha/miniforge3/envs/mlp/include/python3.8 -c cassandra/io/libevwrapper.c -o build/temp.macosx-11.0-arm64-cpython-38/cassandra/io/libevwrapper.o
#       clang -bundle -undefined dynamic_lookup -Wl,-rpath,/Users/rojinashrestha/miniforge3/envs/mlp/lib -L/Users/rojinashrestha/miniforge3/envs/mlp/lib -Wl,-rpath,/Users/rojinashrestha/miniforge3/envs/mlp/lib -L/Users/rojinashrestha/miniforge3/envs/mlp/lib build/temp.macosx-11.0-arm64-cpython-38/cassandra/io/libevwrapper.o -L/usr/local/lib -L/opt/local/lib -lev -o build/lib.macosx-11.0-arm64-cpython-38/cassandra/io/libevwrapper.cpython-38-darwin.so
#       ld: warning: directory not found for option '-L/opt/local/lib'
#       building 'cassandra.cluster' extension
#       clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/rojinashrestha/miniforge3/envs/mlp/include -arch arm64 -fPIC -O2 -isystem /Users/rojinashrestha/miniforge3/envs/mlp/include -arch arm64 -I/Users/rojinashrestha/miniforge3/envs/mlp/include/python3.8 -c cassandra/cluster.c -o build/temp.macosx-11.0-arm64-cpython-38/cassandra/cluster.o -Wno-unused-function
#       cassandra/cluster.c:100508:3: warning: 'tp_print' is deprecated [-Wdeprecated-declarations]
#         0, /*tp_print*/
#         ^
#       /Users/rojinashrestha/miniforge3/envs/mlp/include/python3.8/cpython/object.h:260:5: note: 'tp_print' has been explicitly marked deprecated here
#           Py_DEPRECATED(3.8) int (*tp_print)(PyObject *, FILE *, int);
#           ^
#       /Users/rojinashrestha/miniforge3/envs/mlp/include/python3.8/pyport.h:515:54: note: expanded from macro 'Py_DEPRECATED'
#       #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#                                                            ^
#       cassandra/cluster.c:100633:3: warning: 'tp_print' is deprecated [-Wdeprecated-declarations]
#         0, /*tp_print*/
#         ^
#       /Users/rojinashrestha/miniforge3/envs/mlp/include/python3.8/cpython/object.h:260:5: note: 'tp_print' has been explicitly marked deprecated here
#           Py_DEPRECATED(3.8) int (*tp_print)(PyObject *, FILE *, int);
#           ^
#       /Users/rojinashrestha/miniforge3/envs/mlp/include/python3.8/pyport.h:515:54: note: expanded from macro 'Py_DEPRECATED'
#       #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#                                                            ^
#       cassandra/cluster.c:100754:3: warning: 'tp_print' is deprecated [-Wdeprecated-declarations]
#         0, /*tp_print*/
#         ^
#       /Users/rojinashrestha/miniforge3/envs/mlp/include/python3.8/cpython/object.h:260:5: note: 'tp_print' has been explicitly marked deprecated here
#           Py_DEPRECATED(3.8) int (*tp_print)(PyObject *, FILE *, int);
#           ^
#       /Users/rojinashrestha/miniforge3/envs/mlp/include/python3.8/pyport.h:515:54: note: expanded from macro 'Py_DEPRECATED'
#       #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#                                                            ^
#       cassandra/cluster.c:100871:3: warning: 'tp_print' is deprecated [-Wdeprecated-declarations]
#         0, /*tp_print*/
#         ^
#       /Users/rojinashrestha/miniforge3/envs/mlp/include/python3.8/cpython/object.h:260:5: note: 'tp_print' has been explicitly marked deprecated here
#           Py_DEPRECATED(3.8) int (*tp_print)(PyObject *, FILE *, int);
#           ^
#       /Users/rojinashrestha/miniforge3/envs/mlp/include/python3.8/pyport.h:515:54: note: expanded from macro 'Py_DEPRECATED'
#       #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#                                                            ^
#       cassandra/cluster.c:100996:3: warning: 'tp_print' is deprecated [-Wdeprecated-declarations]
#         0, /*tp_print*/
#         ^
#       /Users/rojinashrestha/miniforge3/envs/mlp/include/python3.8/cpython/object.h:260:5: note: 'tp_print' has been explicitly marked deprecated here
#           Py_DEPRECATED(3.8) int (*tp_print)(PyObject *, FILE *, int);
#           ^
#       /Users/rojinashrestha/miniforge3/envs/mlp/include/python3.8/pyport.h:515:54: note: expanded from macro 'Py_DEPRECATED'
#       #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#                                                            ^
#       cassandra/cluster.c:101109:3: warning: 'tp_print' is deprecated [-Wdeprecated-declarations]
#         0, /*tp_print*/
#         ^
#       /Users/rojinashrestha/miniforge3/envs/mlp/include/python3.8/cpython/object.h:260:5: note: 'tp_print' has been explicitly marked deprecated here
#           Py_DEPRECATED(3.8) int (*tp_print)(PyObject *, FILE *, int);
#           ^
#       /Users/rojinashrestha/miniforge3/envs/mlp/include/python3.8/pyport.h:515:54: note: expanded from macro 'Py_DEPRECATED'
#       #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#                                                            ^
#       cassandra/cluster.c:101255:3: warning: 'tp_print' is deprecated [-Wdeprecated-declarations]
#         0, /*tp_print*/
#         ^
#       /Users/rojinashrestha/miniforge3/envs/mlp/include/python3.8/cpython/object.h:260:5: note: 'tp_print' has been explicitly marked deprecated here
#           Py_DEPRECATED(3.8) int (*tp_print)(PyObject *, FILE *, int);
#           ^
#       /Users/rojinashrestha/miniforge3/envs/mlp/include/python3.8/pyport.h:515:54: note: expanded from macro 'Py_DEPRECATED'
#       #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#                                                            ^
#       cassandra/cluster.c:101387:3: warning: 'tp_print' is deprecated [-Wdeprecated-declarations]
#         0, /*tp_print*/
#         ^
#       /Users/rojinashrestha/miniforge3/envs/mlp/include/python3.8/cpython/object.h:260:5: note: 'tp_print' has been explicitly marked deprecated here
#           Py_DEPRECATED(3.8) int (*tp_print)(PyObject *, FILE *, int);
#           ^
#       /Users/rojinashrestha/miniforge3/envs/mlp/include/python3.8/pyport.h:515:54: note: expanded from macro 'Py_DEPRECATED'
#       #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#                                                            ^
#       cassandra/cluster.c:101504:3: warning: 'tp_print' is deprecated [-Wdeprecated-declarations]
#         0, /*tp_print*/
#         ^
#       /Users/rojinashrestha/miniforge3/envs/mlp/include/python3.8/cpython/object.h:260:5: note: 'tp_print' has been explicitly marked deprecated here
#           Py_DEPRECATED(3.8) int (*tp_print)(PyObject *, FILE *, int);
#           ^
#       /Users/rojinashrestha/miniforge3/envs/mlp/include/python3.8/pyport.h:515:54: note: expanded from macro 'Py_DEPRECATED'
#       #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#                                                            ^
#       cassandra/cluster.c:101629:3: warning: 'tp_print' is deprecated [-Wdeprecated-declarations]
#         0, /*tp_print*/
#         ^
#       /Users/rojinashrestha/miniforge3/envs/mlp/include/python3.8/cpython/object.h:260:5: note: 'tp_print' has been explicitly marked deprecated here
#           Py_DEPRECATED(3.8) int (*tp_print)(PyObject *, FILE *, int);
#           ^
#       /Users/rojinashrestha/miniforge3/envs/mlp/include/python3.8/pyport.h:515:54: note: expanded from macro 'Py_DEPRECATED'
#       #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#                                                            ^
#       cassandra/cluster.c:101742:3: warning: 'tp_print' is deprecated [-Wdeprecated-declarations]
#         0, /*tp_print*/
#         ^
#       /Users/rojinashrestha/miniforge3/envs/mlp/include/python3.8/cpython/object.h:260:5: note: 'tp_print' has been explicitly marked deprecated here
#           Py_DEPRECATED(3.8) int (*tp_print)(PyObject *, FILE *, int);
#           ^
#       /Users/rojinashrestha/miniforge3/envs/mlp/include/python3.8/pyport.h:515:54: note: expanded from macro 'Py_DEPRECATED'
#       #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#                                                            ^
#       cassandra/cluster.c:101855:3: warning: 'tp_print' is deprecated [-Wdeprecated-declarations]
#         0, /*tp_print*/
#         ^
#       /Users/rojinashrestha/miniforge3/envs/mlp/include/python3.8/cpython/object.h:260:5: note: 'tp_print' has been explicitly marked deprecated here
#           Py_DEPRECATED(3.8) int (*tp_print)(PyObject *, FILE *, int);
#           ^
#       /Users/rojinashrestha/miniforge3/envs/mlp/include/python3.8/pyport.h:515:54: note: expanded from macro 'Py_DEPRECATED'
#       #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#                                                            ^
#       cassandra/cluster.c:101994:3: warning: 'tp_print' is deprecated [-Wdeprecated-declarations]
#         0, /*tp_print*/
#         ^
#       /Users/rojinashrestha/miniforge3/envs/mlp/include/python3.8/cpython/object.h:260:5: note: 'tp_print' has been explicitly marked deprecated here
#           Py_DEPRECATED(3.8) int (*tp_print)(PyObject *, FILE *, int);
#           ^
#       /Users/rojinashrestha/miniforge3/envs/mlp/include/python3.8/pyport.h:515:54: note: expanded from macro 'Py_DEPRECATED'
#       #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#                                                            ^
#       cassandra/cluster.c:102126:3: warning: 'tp_print' is deprecated [-Wdeprecated-declarations]
#         0, /*tp_print*/
#         ^
#       /Users/rojinashrestha/miniforge3/envs/mlp/include/python3.8/cpython/object.h:260:5: note: 'tp_print' has been explicitly marked deprecated here
#           Py_DEPRECATED(3.8) int (*tp_print)(PyObject *, FILE *, int);
#           ^
#       /Users/rojinashrestha/miniforge3/envs/mlp/include/python3.8/pyport.h:515:54: note: expanded from macro 'Py_DEPRECATED'
#       #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#                                                            ^
#       cassandra/cluster.c:102244:3: warning: 'tp_print' is deprecated [-Wdeprecated-declarations]
#         0, /*tp_print*/
#         ^
#       /Users/rojinashrestha/miniforge3/envs/mlp/include/python3.8/cpython/object.h:260:5: note: 'tp_print' has been explicitly marked deprecated here
#           Py_DEPRECATED(3.8) int (*tp_print)(PyObject *, FILE *, int);
#           ^
#       /Users/rojinashrestha/miniforge3/envs/mlp/include/python3.8/pyport.h:515:54: note: expanded from macro 'Py_DEPRECATED'
#       #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#                                                            ^
#       cassandra/cluster.c:102376:3: warning: 'tp_print' is deprecated [-Wdeprecated-declarations]
#         0, /*tp_print*/
#         ^
#       /Users/rojinashrestha/miniforge3/envs/mlp/include/python3.8/cpython/object.h:260:5: note: 'tp_print' has been explicitly marked deprecated here
#           Py_DEPRECATED(3.8) int (*tp_print)(PyObject *, FILE *, int);
#           ^
#       /Users/rojinashrestha/miniforge3/envs/mlp/include/python3.8/pyport.h:515:54: note: expanded from macro 'Py_DEPRECATED'
#       #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#                                                            ^
#       cassandra/cluster.c:102501:3: warning: 'tp_print' is deprecated [-Wdeprecated-declarations]
#         0, /*tp_print*/
#         ^
#       /Users/rojinashrestha/miniforge3/envs/mlp/include/python3.8/cpython/object.h:260:5: note: 'tp_print' has been explicitly marked deprecated here
#           Py_DEPRECATED(3.8) int (*tp_print)(PyObject *, FILE *, int);
#           ^
#       /Users/rojinashrestha/miniforge3/envs/mlp/include/python3.8/pyport.h:515:54: note: expanded from macro 'Py_DEPRECATED'
#       #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#                                                            ^
#       cassandra/cluster.c:102626:3: warning: 'tp_print' is deprecated [-Wdeprecated-declarations]
#         0, /*tp_print*/
#         ^
#       /Users/rojinashrestha/miniforge3/envs/mlp/include/python3.8/cpython/object.h:260:5: note: 'tp_print' has been explicitly marked deprecated here
#           Py_DEPRECATED(3.8) int (*tp_print)(PyObject *, FILE *, int);
#           ^
#       /Users/rojinashrestha/miniforge3/envs/mlp/include/python3.8/pyport.h:515:54: note: expanded from macro 'Py_DEPRECATED'
#       #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#                                                            ^
#       cassandra/cluster.c:102743:3: warning: 'tp_print' is deprecated [-Wdeprecated-declarations]
#         0, /*tp_print*/
#         ^
#       /Users/rojinashrestha/miniforge3/envs/mlp/include/python3.8/cpython/object.h:260:5: note: 'tp_print' has been explicitly marked deprecated here
#           Py_DEPRECATED(3.8) int (*tp_print)(PyObject *, FILE *, int);
#           ^
#       /Users/rojinashrestha/miniforge3/envs/mlp/include/python3.8/pyport.h:515:54: note: expanded from macro 'Py_DEPRECATED'
#       #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#                                                            ^
#       cassandra/cluster.c:102861:3: warning: 'tp_print' is deprecated [-Wdeprecated-declarations]
#         0, /*tp_print*/
#         ^
#       /Users/rojinashrestha/miniforge3/envs/mlp/include/python3.8/cpython/object.h:260:5: note: 'tp_print' has been explicitly marked deprecated here
#           Py_DEPRECATED(3.8) int (*tp_print)(PyObject *, FILE *, int);
#           ^
#       /Users/rojinashrestha/miniforge3/envs/mlp/include/python3.8/pyport.h:515:54: note: expanded from macro 'Py_DEPRECATED'
#       #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#                                                            ^
#       cassandra/cluster.c:102978:3: warning: 'tp_print' is deprecated [-Wdeprecated-declarations]
#         0, /*tp_print*/
#         ^
#       /Users/rojinashrestha/miniforge3/envs/mlp/include/python3.8/cpython/object.h:260:5: note: 'tp_print' has been explicitly marked deprecated here
#           Py_DEPRECATED(3.8) int (*tp_print)(PyObject *, FILE *, int);
#           ^
#       /Users/rojinashrestha/miniforge3/envs/mlp/include/python3.8/pyport.h:515:54: note: expanded from macro 'Py_DEPRECATED'
#       #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#                                                            ^
#       cassandra/cluster.c:103096:3: warning: 'tp_print' is deprecated [-Wdeprecated-declarations]
#         0, /*tp_print*/
#         ^
#       /Users/rojinashrestha/miniforge3/envs/mlp/include/python3.8/cpython/object.h:260:5: note: 'tp_print' has been explicitly marked deprecated here
#           Py_DEPRECATED(3.8) int (*tp_print)(PyObject *, FILE *, int);
#           ^
#       /Users/rojinashrestha/miniforge3/envs/mlp/include/python3.8/pyport.h:515:54: note: expanded from macro 'Py_DEPRECATED'
#       #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#                                                            ^
#       cassandra/cluster.c:103213:3: warning: 'tp_print' is deprecated [-Wdeprecated-declarations]
#         0, /*tp_print*/
#         ^
#       /Users/rojinashrestha/miniforge3/envs/mlp/include/python3.8/cpython/object.h:260:5: note: 'tp_print' has been explicitly marked deprecated here
#           Py_DEPRECATED(3.8) int (*tp_print)(PyObject *, FILE *, int);
#           ^
#       /Users/rojinashrestha/miniforge3/envs/mlp/include/python3.8/pyport.h:515:54: note: expanded from macro 'Py_DEPRECATED'
#       #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#                                                            ^
#       cassandra/cluster.c:103338:3: warning: 'tp_print' is deprecated [-Wdeprecated-declarations]
#         0, /*tp_print*/
#         ^
#       /Users/rojinashrestha/miniforge3/envs/mlp/include/python3.8/cpython/object.h:260:5: note: 'tp_print' has been explicitly marked deprecated here
#           Py_DEPRECATED(3.8) int (*tp_print)(PyObject *, FILE *, int);
#           ^
#       /Users/rojinashrestha/miniforge3/envs/mlp/include/python3.8/pyport.h:515:54: note: expanded from macro 'Py_DEPRECATED'
#       #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#                                                            ^
#       cassandra/cluster.c:103463:3: warning: 'tp_print' is deprecated [-Wdeprecated-declarations]
#         0, /*tp_print*/
#         ^
#       /Users/rojinashrestha/miniforge3/envs/mlp/include/python3.8/cpython/object.h:260:5: note: 'tp_print' has been explicitly marked deprecated here
#           Py_DEPRECATED(3.8) int (*tp_print)(PyObject *, FILE *, int);
#           ^
#       /Users/rojinashrestha/miniforge3/envs/mlp/include/python3.8/pyport.h:515:54: note: expanded from macro 'Py_DEPRECATED'
#       #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#                                                            ^
#       cassandra/cluster.c:103588:3: warning: 'tp_print' is deprecated [-Wdeprecated-declarations]
#         0, /*tp_print*/
#         ^
#       /Users/rojinashrestha/miniforge3/envs/mlp/include/python3.8/cpython/object.h:260:5: note: 'tp_print' has been explicitly marked deprecated here
#           Py_DEPRECATED(3.8) int (*tp_print)(PyObject *, FILE *, int);
#           ^
#       /Users/rojinashrestha/miniforge3/envs/mlp/include/python3.8/pyport.h:515:54: note: expanded from macro 'Py_DEPRECATED'
#       #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#                                                            ^
#       cassandra/cluster.c:103713:3: warning: 'tp_print' is deprecated [-Wdeprecated-declarations]
#         0, /*tp_print*/
#         ^
#       /Users/rojinashrestha/miniforge3/envs/mlp/include/python3.8/cpython/object.h:260:5: note: 'tp_print' has been explicitly marked deprecated here
#           Py_DEPRECATED(3.8) int (*tp_print)(PyObject *, FILE *, int);
#           ^
#       /Users/rojinashrestha/miniforge3/envs/mlp/include/python3.8/pyport.h:515:54: note: expanded from macro 'Py_DEPRECATED'
#       #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#                                                            ^
#       cassandra/cluster.c:118851:5: warning: 'tp_print' is deprecated [-Wdeprecated-declarations]
#           0,
#           ^
#       /Users/rojinashrestha/miniforge3/envs/mlp/include/python3.8/cpython/object.h:260:5: note: 'tp_print' has been explicitly marked deprecated here
#           Py_DEPRECATED(3.8) int (*tp_print)(PyObject *, FILE *, int);
#           ^
#       /Users/rojinashrestha/miniforge3/envs/mlp/include/python3.8/pyport.h:515:54: note: expanded from macro 'Py_DEPRECATED'
#       #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#                                                            ^
#       cassandra/cluster.c:122585:5: warning: 'tp_print' is deprecated [-Wdeprecated-declarations]
#           0,
#           ^
#       /Users/rojinashrestha/miniforge3/envs/mlp/include/python3.8/cpython/object.h:260:5: note: 'tp_print' has been explicitly marked deprecated here
#           Py_DEPRECATED(3.8) int (*tp_print)(PyObject *, FILE *, int);
#           ^
#       /Users/rojinashrestha/miniforge3/envs/mlp/include/python3.8/pyport.h:515:54: note: expanded from macro 'Py_DEPRECATED'
#       #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#                                                            ^
#       29 warnings generated.
#       clang -bundle -undefined dynamic_lookup -Wl,-rpath,/Users/rojinashrestha/miniforge3/envs/mlp/lib -L/Users/rojinashrestha/miniforge3/envs/mlp/lib -Wl,-rpath,/Users/rojinashrestha/miniforge3/envs/mlp/lib -L/Users/rojinashrestha/miniforge3/envs/mlp/lib build/temp.macosx-11.0-arm64-cpython-38/cassandra/cluster.o -o build/lib.macosx-11.0-arm64-cpython-38/cassandra/cluster.cpython-38-darwin.so
#       building 'cassandra.concurrent' extension
#       clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/rojinashrestha/miniforge3/envs/mlp/include -arch arm64 -fPIC -O2 -isystem /Users/rojinashrestha/miniforge3/envs/mlp/include -arch arm64 -I/Users/rojinashrestha/miniforge3/envs/mlp/include/python3.8 -c cassandra/concurrent.c -o build/temp.macosx-11.0-arm64-cpython-38/cassandra/concurrent.o -Wno-unused-function
#       cassandra/concurrent.c:7285:3: warning: 'tp_print' is deprecated [-Wdeprecated-declarations]
#         0, /*tp_print*/
#         ^
#       /Users/rojinashrestha/miniforge3/envs/mlp/include/python3.8/cpython/object.h:260:5: note: 'tp_print' has been explicitly marked deprecated here
#           Py_DEPRECATED(3.8) int (*tp_print)(PyObject *, FILE *, int);
#           ^
#       /Users/rojinashrestha/miniforge3/envs/mlp/include/python3.8/pyport.h:515:54: note: expanded from macro 'Py_DEPRECATED'
#       #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#                                                            ^
#       cassandra/concurrent.c:10755:5: warning: 'tp_print' is deprecated [-Wdeprecated-declarations]
#           0,
#           ^
#       /Users/rojinashrestha/miniforge3/envs/mlp/include/python3.8/cpython/object.h:260:5: note: 'tp_print' has been explicitly marked deprecated here
#           Py_DEPRECATED(3.8) int (*tp_print)(PyObject *, FILE *, int);
#           ^
#       /Users/rojinashrestha/miniforge3/envs/mlp/include/python3.8/pyport.h:515:54: note: expanded from macro 'Py_DEPRECATED'
#       #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#                                                            ^
#       cassandra/concurrent.c:12672:5: warning: 'tp_print' is deprecated [-Wdeprecated-declarations]
#           0,
#           ^
#       /Users/rojinashrestha/miniforge3/envs/mlp/include/python3.8/cpython/object.h:260:5: note: 'tp_print' has been explicitly marked deprecated here
#           Py_DEPRECATED(3.8) int (*tp_print)(PyObject *, FILE *, int);
#           ^
#       /Users/rojinashrestha/miniforge3/envs/mlp/include/python3.8/pyport.h:515:54: note: expanded from macro 'Py_DEPRECATED'
#       #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#                                                            ^
#       3 warnings generated.
#       clang -bundle -undefined dynamic_lookup -Wl,-rpath,/Users/rojinashrestha/miniforge3/envs/mlp/lib -L/Users/rojinashrestha/miniforge3/envs/mlp/lib -Wl,-rpath,/Users/rojinashrestha/miniforge3/envs/mlp/lib -L/Users/rojinashrestha/miniforge3/envs/mlp/lib build/temp.macosx-11.0-arm64-cpython-38/cassandra/concurrent.o -o build/lib.macosx-11.0-arm64-cpython-38/cassandra/concurrent.cpython-38-darwin.so
#       building 'cassandra.connection' extension
#       clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/rojinashrestha/miniforge3/envs/mlp/include -arch arm64 -fPIC -O2 -isystem /Users/rojinashrestha/miniforge3/envs/mlp/include -arch arm64 -I/Users/rojinashrestha/miniforge3/envs/mlp/include/python3.8 -c cassandra/connection.c -o build/temp.macosx-11.0-arm64-cpython-38/cassandra/connection.o -Wno-unused-function
#       cassandra/connection.c:42847:3: warning: 'tp_print' is deprecated [-Wdeprecated-declarations]
#         0, /*tp_print*/
#         ^
#       /Users/rojinashrestha/miniforge3/envs/mlp/include/python3.8/cpython/object.h:260:5: note: 'tp_print' has been explicitly marked deprecated here
#           Py_DEPRECATED(3.8) int (*tp_print)(PyObject *, FILE *, int);
#           ^
#       /Users/rojinashrestha/miniforge3/envs/mlp/include/python3.8/pyport.h:515:54: note: expanded from macro 'Py_DEPRECATED'
#       #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#                                                            ^
#       cassandra/connection.c:42960:3: warning: 'tp_print' is deprecated [-Wdeprecated-declarations]
#         0, /*tp_print*/
#         ^
#       /Users/rojinashrestha/miniforge3/envs/mlp/include/python3.8/cpython/object.h:260:5: note: 'tp_print' has been explicitly marked deprecated here
#           Py_DEPRECATED(3.8) int (*tp_print)(PyObject *, FILE *, int);
#           ^
#       /Users/rojinashrestha/miniforge3/envs/mlp/include/python3.8/pyport.h:515:54: note: expanded from macro 'Py_DEPRECATED'
#       #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#                                                            ^
#       cassandra/connection.c:43089:3: warning: 'tp_print' is deprecated [-Wdeprecated-declarations]
#         0, /*tp_print*/
#         ^
#       /Users/rojinashrestha/miniforge3/envs/mlp/include/python3.8/cpython/object.h:260:5: note: 'tp_print' has been explicitly marked deprecated here
#           Py_DEPRECATED(3.8) int (*tp_print)(PyObject *, FILE *, int);
#           ^
# ...
#       copying build/lib.macosx-11.0-arm64-cpython-38/cassandra/query.py -> build/bdist.macosx-11.0-arm64/wheel/cassandra
#       copying build/lib.macosx-11.0-arm64-cpython-38/cassandra/cython_utils.cpython-38-darwin.so -> build/bdist.macosx-11.0-arm64/wheel/cassandra
#       copying build/lib.macosx-11.0-arm64-cpython-38/cassandra/deserializers.pxd -> build/bdist.macosx-11.0-arm64/wheel/cassandra
#       copying build/lib.macosx-11.0-arm64-cpython-38/cassandra/cython_marshal.pyx -> build/bdist.macosx-11.0-arm64/wheel/cassandra
#       copying build/lib.macosx-11.0-arm64-cpython-38/cassandra/concurrent.cpython-38-darwin.so -> build/bdist.macosx-11.0-arm64/wheel/cassandra
#       copying build/lib.macosx-11.0-arm64-cpython-38/cassandra/row_parser.pyx -> build/bdist.macosx-11.0-arm64/wheel/cassandra
#       copying build/lib.macosx-11.0-arm64-cpython-38/cassandra/util.py -> build/bdist.macosx-11.0-arm64/wheel/cassandra
#       copying build/lib.macosx-11.0-arm64-cpython-38/cassandra/timestamps.py -> build/bdist.macosx-11.0-arm64/wheel/cassandra
#       copying build/lib.macosx-11.0-arm64-cpython-38/cassandra/protocol.cpython-38-darwin.so -> build/bdist.macosx-11.0-arm64/wheel/cassandra
#       copying build/lib.macosx-11.0-arm64-cpython-38/cassandra/numpy_parser.pyx -> build/bdist.macosx-11.0-arm64/wheel/cassandra
#       copying build/lib.macosx-11.0-arm64-cpython-38/cassandra/cqltypes.py -> build/bdist.macosx-11.0-arm64/wheel/cassandra
#       copying build/lib.macosx-11.0-arm64-cpython-38/cassandra/protocol.py -> build/bdist.macosx-11.0-arm64/wheel/cassandra
#       copying build/lib.macosx-11.0-arm64-cpython-38/cassandra/row_parser.cpython-38-darwin.so -> build/bdist.macosx-11.0-arm64/wheel/cassandra
#       copying build/lib.macosx-11.0-arm64-cpython-38/cassandra/parsing.pxd -> build/bdist.macosx-11.0-arm64/wheel/cassandra
#       creating build/bdist.macosx-11.0-arm64/wheel/cassandra/io
#       copying build/lib.macosx-11.0-arm64-cpython-38/cassandra/io/asyncorereactor.py -> build/bdist.macosx-11.0-arm64/wheel/cassandra/io
#       copying build/lib.macosx-11.0-arm64-cpython-38/cassandra/io/libevwrapper.c -> build/bdist.macosx-11.0-arm64/wheel/cassandra/io
#       copying build/lib.macosx-11.0-arm64-cpython-38/cassandra/io/asyncioreactor.py -> build/bdist.macosx-11.0-arm64/wheel/cassandra/io
#       copying build/lib.macosx-11.0-arm64-cpython-38/cassandra/io/twistedreactor.py -> build/bdist.macosx-11.0-arm64/wheel/cassandra/io
#       copying build/lib.macosx-11.0-arm64-cpython-38/cassandra/io/__init__.py -> build/bdist.macosx-11.0-arm64/wheel/cassandra/io
#       copying build/lib.macosx-11.0-arm64-cpython-38/cassandra/io/geventreactor.py -> build/bdist.macosx-11.0-arm64/wheel/cassandra/io
#       copying build/lib.macosx-11.0-arm64-cpython-38/cassandra/io/libevwrapper.cpython-38-darwin.so -> build/bdist.macosx-11.0-arm64/wheel/cassandra/io
#       copying build/lib.macosx-11.0-arm64-cpython-38/cassandra/io/libevreactor.py -> build/bdist.macosx-11.0-arm64/wheel/cassandra/io
#       copying build/lib.macosx-11.0-arm64-cpython-38/cassandra/io/eventletreactor.py -> build/bdist.macosx-11.0-arm64/wheel/cassandra/io
#       creating build/bdist.macosx-11.0-arm64/wheel/cassandra/graph
#       copying build/lib.macosx-11.0-arm64-cpython-38/cassandra/graph/query.py -> build/bdist.macosx-11.0-arm64/wheel/cassandra/graph
#       copying build/lib.macosx-11.0-arm64-cpython-38/cassandra/graph/graphson.py -> build/bdist.macosx-11.0-arm64/wheel/cassandra/graph
#       copying build/lib.macosx-11.0-arm64-cpython-38/cassandra/graph/__init__.py -> build/bdist.macosx-11.0-arm64/wheel/cassandra/graph
#       copying build/lib.macosx-11.0-arm64-cpython-38/cassandra/graph/types.py -> build/bdist.macosx-11.0-arm64/wheel/cassandra/graph
#       copying build/lib.macosx-11.0-arm64-cpython-38/cassandra/type_codes.pxd -> build/bdist.macosx-11.0-arm64/wheel/cassandra
#       copying build/lib.macosx-11.0-arm64-cpython-38/cassandra/buffer.pxd -> build/bdist.macosx-11.0-arm64/wheel/cassandra
#       copying build/lib.macosx-11.0-arm64-cpython-38/cassandra/ioutils.cpython-38-darwin.so -> build/bdist.macosx-11.0-arm64/wheel/cassandra
#       copying build/lib.macosx-11.0-arm64-cpython-38/cassandra/__init__.py -> build/bdist.macosx-11.0-arm64/wheel/cassandra
#       copying build/lib.macosx-11.0-arm64-cpython-38/cassandra/murmur3.py -> build/bdist.macosx-11.0-arm64/wheel/cassandra
#       copying build/lib.macosx-11.0-arm64-cpython-38/cassandra/encoder.py -> build/bdist.macosx-11.0-arm64/wheel/cassandra
#       copying build/lib.macosx-11.0-arm64-cpython-38/cassandra/cmurmur3.c -> build/bdist.macosx-11.0-arm64/wheel/cassandra
#       copying build/lib.macosx-11.0-arm64-cpython-38/cassandra/cluster.cpython-38-darwin.so -> build/bdist.macosx-11.0-arm64/wheel/cassandra
#       copying build/lib.macosx-11.0-arm64-cpython-38/cassandra/bytesio.cpython-38-darwin.so -> build/bdist.macosx-11.0-arm64/wheel/cassandra
#       copying build/lib.macosx-11.0-arm64-cpython-38/cassandra/connection.py -> build/bdist.macosx-11.0-arm64/wheel/cassandra
#       copying build/lib.macosx-11.0-arm64-cpython-38/cassandra/parsing.cpython-38-darwin.so -> build/bdist.macosx-11.0-arm64/wheel/cassandra
#       copying build/lib.macosx-11.0-arm64-cpython-38/cassandra/cluster.py -> build/bdist.macosx-11.0-arm64/wheel/cassandra
#       copying build/lib.macosx-11.0-arm64-cpython-38/cassandra/parsing.pyx -> build/bdist.macosx-11.0-arm64/wheel/cassandra
#       copying build/lib.macosx-11.0-arm64-cpython-38/cassandra/query.cpython-38-darwin.so -> build/bdist.macosx-11.0-arm64/wheel/cassandra
#       copying build/lib.macosx-11.0-arm64-cpython-38/cassandra/cython_deps.py -> build/bdist.macosx-11.0-arm64/wheel/cassandra
#       copying build/lib.macosx-11.0-arm64-cpython-38/cassandra/type_codes.py -> build/bdist.macosx-11.0-arm64/wheel/cassandra
#       copying build/lib.macosx-11.0-arm64-cpython-38/cassandra/pool.cpython-38-darwin.so -> build/bdist.macosx-11.0-arm64/wheel/cassandra
#       copying build/lib.macosx-11.0-arm64-cpython-38/cassandra/cqltypes.cpython-38-darwin.so -> build/bdist.macosx-11.0-arm64/wheel/cassandra
#       copying build/lib.macosx-11.0-arm64-cpython-38/cassandra/ioutils.pyx -> build/bdist.macosx-11.0-arm64/wheel/cassandra
#       copying build/lib.macosx-11.0-arm64-cpython-38/cassandra/tuple.pxd -> build/bdist.macosx-11.0-arm64/wheel/cassandra
#       copying build/lib.macosx-11.0-arm64-cpython-38/cassandra/util.cpython-38-darwin.so -> build/bdist.macosx-11.0-arm64/wheel/cassandra
#       copying build/lib.macosx-11.0-arm64-cpython-38/cassandra/cmurmur3.cpython-38-darwin.so -> build/bdist.macosx-11.0-arm64/wheel/cassandra
#       copying build/lib.macosx-11.0-arm64-cpython-38/cassandra/numpyFlags.h -> build/bdist.macosx-11.0-arm64/wheel/cassandra
#       copying build/lib.macosx-11.0-arm64-cpython-38/cassandra/segment.py -> build/bdist.macosx-11.0-arm64/wheel/cassandra
#       copying build/lib.macosx-11.0-arm64-cpython-38/cassandra/connection.cpython-38-darwin.so -> build/bdist.macosx-11.0-arm64/wheel/cassandra
#       copying build/lib.macosx-11.0-arm64-cpython-38/cassandra/obj_parser.pyx -> build/bdist.macosx-11.0-arm64/wheel/cassandra
#       copying build/lib.macosx-11.0-arm64-cpython-38/cassandra/deserializers.pyx -> build/bdist.macosx-11.0-arm64/wheel/cassandra
#       copying build/lib.macosx-11.0-arm64-cpython-38/cassandra/metadata.cpython-38-darwin.so -> build/bdist.macosx-11.0-arm64/wheel/cassandra
#       copying build/lib.macosx-11.0-arm64-cpython-38/cassandra/pool.py -> build/bdist.macosx-11.0-arm64/wheel/cassandra
#       creating build/bdist.macosx-11.0-arm64/wheel/cassandra/cqlengine
#       copying build/lib.macosx-11.0-arm64-cpython-38/cassandra/cqlengine/functions.py -> build/bdist.macosx-11.0-arm64/wheel/cassandra/cqlengine
#       copying build/lib.macosx-11.0-arm64-cpython-38/cassandra/cqlengine/usertype.py -> build/bdist.macosx-11.0-arm64/wheel/cassandra/cqlengine
#       copying build/lib.macosx-11.0-arm64-cpython-38/cassandra/cqlengine/models.py -> build/bdist.macosx-11.0-arm64/wheel/cassandra/cqlengine
#       copying build/lib.macosx-11.0-arm64-cpython-38/cassandra/cqlengine/query.py -> build/bdist.macosx-11.0-arm64/wheel/cassandra/cqlengine
#       copying build/lib.macosx-11.0-arm64-cpython-38/cassandra/cqlengine/__init__.py -> build/bdist.macosx-11.0-arm64/wheel/cassandra/cqlengine
#       copying build/lib.macosx-11.0-arm64-cpython-38/cassandra/cqlengine/columns.py -> build/bdist.macosx-11.0-arm64/wheel/cassandra/cqlengine
#       copying build/lib.macosx-11.0-arm64-cpython-38/cassandra/cqlengine/connection.py -> build/bdist.macosx-11.0-arm64/wheel/cassandra/cqlengine
#       copying build/lib.macosx-11.0-arm64-cpython-38/cassandra/cqlengine/management.py -> build/bdist.macosx-11.0-arm64/wheel/cassandra/cqlengine
#       copying build/lib.macosx-11.0-arm64-cpython-38/cassandra/cqlengine/statements.py -> build/bdist.macosx-11.0-arm64/wheel/cassandra/cqlengine
#       copying build/lib.macosx-11.0-arm64-cpython-38/cassandra/cqlengine/operators.py -> build/bdist.macosx-11.0-arm64/wheel/cassandra/cqlengine
#       copying build/lib.macosx-11.0-arm64-cpython-38/cassandra/cqlengine/named.py -> build/bdist.macosx-11.0-arm64/wheel/cassandra/cqlengine
#       copying build/lib.macosx-11.0-arm64-cpython-38/cassandra/policies.py -> build/bdist.macosx-11.0-arm64/wheel/cassandra
#       copying build/lib.macosx-11.0-arm64-cpython-38/cassandra/cython_marshal.cpython-38-darwin.so -> build/bdist.macosx-11.0-arm64/wheel/cassandra
#       copying build/lib.macosx-11.0-arm64-cpython-38/cassandra/cython_utils.pxd -> build/bdist.macosx-11.0-arm64/wheel/cassandra
#       copying build/lib.macosx-11.0-arm64-cpython-38/cassandra/bytesio.pyx -> build/bdist.macosx-11.0-arm64/wheel/cassandra
#       creating build/bdist.macosx-11.0-arm64/wheel/cassandra/datastax
#       creating build/bdist.macosx-11.0-arm64/wheel/cassandra/datastax/insights
#       copying build/lib.macosx-11.0-arm64-cpython-38/cassandra/datastax/insights/registry.py -> build/bdist.macosx-11.0-arm64/wheel/cassandra/datastax/insights
#       copying build/lib.macosx-11.0-arm64-cpython-38/cassandra/datastax/insights/util.py -> build/bdist.macosx-11.0-arm64/wheel/cassandra/datastax/insights
#       copying build/lib.macosx-11.0-arm64-cpython-38/cassandra/datastax/insights/serializers.py -> build/bdist.macosx-11.0-arm64/wheel/cassandra/datastax/insights
#       copying build/lib.macosx-11.0-arm64-cpython-38/cassandra/datastax/insights/reporter.py -> build/bdist.macosx-11.0-arm64/wheel/cassandra/datastax/insights
#       copying build/lib.macosx-11.0-arm64-cpython-38/cassandra/datastax/insights/__init__.py -> build/bdist.macosx-11.0-arm64/wheel/cassandra/datastax/insights
#       creating build/bdist.macosx-11.0-arm64/wheel/cassandra/datastax/graph
#       copying build/lib.macosx-11.0-arm64-cpython-38/cassandra/datastax/graph/query.py -> build/bdist.macosx-11.0-arm64/wheel/cassandra/datastax/graph
#       copying build/lib.macosx-11.0-arm64-cpython-38/cassandra/datastax/graph/graphson.py -> build/bdist.macosx-11.0-arm64/wheel/cassandra/datastax/graph
#       creating build/bdist.macosx-11.0-arm64/wheel/cassandra/datastax/graph/fluent
#       copying build/lib.macosx-11.0-arm64-cpython-38/cassandra/datastax/graph/fluent/predicates.py -> build/bdist.macosx-11.0-arm64/wheel/cassandra/datastax/graph/fluent
#       copying build/lib.macosx-11.0-arm64-cpython-38/cassandra/datastax/graph/fluent/query.py -> build/bdist.macosx-11.0-arm64/wheel/cassandra/datastax/graph/fluent
#       copying build/lib.macosx-11.0-arm64-cpython-38/cassandra/datastax/graph/fluent/_serializers.py -> build/bdist.macosx-11.0-arm64/wheel/cassandra/datastax/graph/fluent
#       copying build/lib.macosx-11.0-arm64-cpython-38/cassandra/datastax/graph/fluent/serializers.py -> build/bdist.macosx-11.0-arm64/wheel/cassandra/datastax/graph/fluent
#       copying build/lib.macosx-11.0-arm64-cpython-38/cassandra/datastax/graph/fluent/_query.py -> build/bdist.macosx-11.0-arm64/wheel/cassandra/datastax/graph/fluent
#       copying build/lib.macosx-11.0-arm64-cpython-38/cassandra/datastax/graph/fluent/__init__.py -> build/bdist.macosx-11.0-arm64/wheel/cassandra/datastax/graph/fluent
#       copying build/lib.macosx-11.0-arm64-cpython-38/cassandra/datastax/graph/fluent/_predicates.py -> build/bdist.macosx-11.0-arm64/wheel/cassandra/datastax/graph/fluent
#       copying build/lib.macosx-11.0-arm64-cpython-38/cassandra/datastax/graph/__init__.py -> build/bdist.macosx-11.0-arm64/wheel/cassandra/datastax/graph
#       copying build/lib.macosx-11.0-arm64-cpython-38/cassandra/datastax/graph/types.py -> build/bdist.macosx-11.0-arm64/wheel/cassandra/datastax/graph
#       copying build/lib.macosx-11.0-arm64-cpython-38/cassandra/datastax/__init__.py -> build/bdist.macosx-11.0-arm64/wheel/cassandra/datastax
#       creating build/bdist.macosx-11.0-arm64/wheel/cassandra/datastax/cloud
#       copying build/lib.macosx-11.0-arm64-cpython-38/cassandra/datastax/cloud/__init__.py -> build/bdist.macosx-11.0-arm64/wheel/cassandra/datastax/cloud
#       running install_egg_info
#       Copying cassandra_driver.egg-info to build/bdist.macosx-11.0-arm64/wheel/cassandra_driver-3.25.0-py3.8.egg-info
#       running install_scripts
#       Traceback (most recent call last):
#         File "<string>", line 2, in <module>
#         File "<pip-setuptools-caller>", line 34, in <module>
#         File "/private/var/folders/sn/b8252hqj551fq4386bsnpn800000gn/T/pip-install-wt2gnbyu/cassandra-driver_a670d6ab7456443787c88025d42dad38/setup.py", line 457, in <module>
#           run_setup(None)
#         File "/private/var/folders/sn/b8252hqj551fq4386bsnpn800000gn/T/pip-install-wt2gnbyu/cassandra-driver_a670d6ab7456443787c88025d42dad38/setup.py", line 416, in run_setup
#           setup(
#         File "/Users/rojinashrestha/miniforge3/envs/mlp/lib/python3.8/site-packages/setuptools/__init__.py", line 87, in setup
#           return distutils.core.setup(**attrs)
#         File "/Users/rojinashrestha/miniforge3/envs/mlp/lib/python3.8/site-packages/setuptools/_distutils/core.py", line 148, in setup
#           return run_commands(dist)
#         File "/Users/rojinashrestha/miniforge3/envs/mlp/lib/python3.8/site-packages/setuptools/_distutils/core.py", line 163, in run_commands
#           dist.run_commands()
#         File "/Users/rojinashrestha/miniforge3/envs/mlp/lib/python3.8/site-packages/setuptools/_distutils/dist.py", line 967, in run_commands
#           self.run_command(cmd)
#         File "/Users/rojinashrestha/miniforge3/envs/mlp/lib/python3.8/site-packages/setuptools/dist.py", line 1214, in run_command
#           super().run_command(command)
#         File "/Users/rojinashrestha/miniforge3/envs/mlp/lib/python3.8/site-packages/setuptools/_distutils/dist.py", line 986, in run_command
#           cmd_obj.run()
#         File "/Users/rojinashrestha/miniforge3/envs/mlp/lib/python3.8/site-packages/wheel/bdist_wheel.py", line 328, in run
#           impl_tag, abi_tag, plat_tag = self.get_tag()
#         File "/Users/rojinashrestha/miniforge3/envs/mlp/lib/python3.8/site-packages/wheel/bdist_wheel.py", line 278, in get_tag
#           assert tag in supported_tags, "would build wheel with unsupported tag {}".format(tag)
#       AssertionError: would build wheel with unsupported tag ('cp38', 'cp38', 'macosx_11_0_arm64')
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for cassandra-driver
#   Running setup.py clean for cassandra-driver
# Failed to build cassandra-driver
# Installing collected packages: click, geomet, cassandra-driver
#   Running setup.py install for cassandra-driver ... done
#   DEPRECATION: cassandra-driver was installed using the legacy 'setup.py install' method, because a wheel could not be built for it. A possible replacement is to fix the wheel build issue reported above. Discussion can be found at https://github.com/pypa/pip/issues/8368
# Successfully installed cassandra-driver-3.25.0 click-8.1.3 geomet-0.2.1.post1

# %% [markdown]
# #### Creating list of filepaths to process original event csv data files

# %%
# checking your current working directory
print(os.getcwd())

# Get your current folder and subfolder event data
filepath = os.getcwd() + '/event_data'

# Create a for loop to create a list of files and collect each filepath
for root, dirs, files in os.walk(filepath):
    
# join the file path and roots with the subdirectories using glob
    file_path_list = glob.glob(os.path.join(root,'*'))
    #print(file_path_list)
# Out:
# /Users/rojinashrestha/Data Modeling with Cassandra/home

# %% [markdown]
# #### Processing the files to create the data file csv that will be used for Apache Casssandra tables

# %%
# initiating an empty list of rows that will be generated from each file
full_data_rows_list = [] 
    
# for every filepath in the file path list 
for f in file_path_list:

# reading csv file 
    with open(f, 'r', encoding = 'utf8', newline='') as csvfile: 
        # creating a csv reader object 
        csvreader = csv.reader(csvfile) 
        next(csvreader)
        
 # extracting each data row one by one and append it        
        for line in csvreader:
            #print(line)
            full_data_rows_list.append(line) 
            
# uncomment the code below if you would like to get total number of rows 
#print(len(full_data_rows_list))
# uncomment the code below if you would like to check to see what the list of event data rows will look like
#print(full_data_rows_list)

# creating a smaller event data csv file called event_datafile_full csv that will be used to insert data into the \
# Apache Cassandra tables
csv.register_dialect('myDialect', quoting=csv.QUOTE_ALL, skipinitialspace=True)

with open('event_datafile_new.csv', 'w', encoding = 'utf8', newline='') as f:
    writer = csv.writer(f, dialect='myDialect')
    writer.writerow(['artist','firstName','gender','itemInSession','lastName','length',\
                'level','location','sessionId','song','userId'])
    for row in full_data_rows_list:
        if (row[0] == ''):
            continue
        writer.writerow((row[0], row[2], row[3], row[4], row[5], row[6], row[7], row[8], row[12], row[13], row[16]))

# %%
# check the number of rows in your csv file
with open('event_datafile_new.csv', 'r', encoding = 'utf8') as f:
    print(sum(1 for line in f))
# Out:
# 6821

# %% [markdown]
# # Part II. Complete the Apache Cassandra coding portion of your project.
#
# ## Now you are ready to work with the CSV file titled <font color=red>event_datafile_new.csv</font>, located within the Workspace directory.  The event_datafile_new.csv contains the following columns:
# - artist
# - firstName of user
# - gender of user
# - item number in session
# - last name of user
# - length of the song
# - level (paid or free song)
# - location of the user
# - sessionId
# - song title
# - userId
#
# The image below is a screenshot of what the denormalized data should appear like in the <font color=red>**event_datafile_new.csv**</font> after the code above is run:<br>
#
# <img src="images/image_event_datafile_new.jpg">

# %% [markdown]
# ## Begin writing your Apache Cassandra code in the cells below

# %% [markdown]
# #### Creating a Cluster

# %%
# This should make a connection to a Cassandra instance your local machine 
# (127.0.0.1)

from cassandra.cluster import Cluster
cluster = Cluster(['192.168.0.1', '192.168.0.2'])

# To establish connection and begin executing queries, need a session
session = cluster.connect()
# Out:
# ---------------------------------------------------------------------------
# NoHostAvailable                           Traceback (most recent call last)
# Input In [27], in <cell line: 8>()
#       5 cluster = Cluster(['192.168.0.1', '192.168.0.2'])
#       7 # To establish connection and begin executing queries, need a session
# ----> 8 session = cluster.connect()
#
# File ~/miniforge3/envs/mlp/lib/python3.8/site-packages/cassandra/cluster.py:1667, in cassandra.cluster.Cluster.connect()
#
# File ~/miniforge3/envs/mlp/lib/python3.8/site-packages/cassandra/cluster.py:1703, in cassandra.cluster.Cluster.connect()
#
# File ~/miniforge3/envs/mlp/lib/python3.8/site-packages/cassandra/cluster.py:1690, in cassandra.cluster.Cluster.connect()
#
# File ~/miniforge3/envs/mlp/lib/python3.8/site-packages/cassandra/cluster.py:3488, in cassandra.cluster.ControlConnection.connect()
#
# File ~/miniforge3/envs/mlp/lib/python3.8/site-packages/cassandra/cluster.py:3533, in cassandra.cluster.ControlConnection._reconnect_internal()
#
# NoHostAvailable: ('Unable to connect to any servers', {'192.168.0.1:9042': ConnectionRefusedError(61, "Tried connecting to [('192.168.0.1', 9042)]. Last error: Connection refused"), '192.168.0.2:9042': OSError(64, "Tried connecting to [('192.168.0.2', 9042)]. Last error: Host is down")})

# %% [markdown]
# #### Create Keyspace

# %%
# TO-DO: Create a Keyspace 
session.execute("""
    CREATE KEYSPACE IF NOT EXISTS sparkify
    WITH REPLICATION = {'class' : 'SimpleStrategy','replication_factor':1}

""")

# %% [markdown]
# #### Set Keyspace

# %%
# TO-DO: Set KEYSPACE to the keyspace specified above
session.set_keyspace('sparkify')

# %% [markdown]
# ### Now we need to create tables to run the following queries. Remember, with Apache Cassandra you model the database tables on the queries you want to run.

# %% [markdown]
# ## Create queries to ask the following three questions of the data
#
# ### 1. Give me the artist, song title and song's length in the music app history that was heard during  sessionId = 338, and itemInSession  = 4
#
#
# ### 2. Give me only the following: name of artist, song (sorted by itemInSession) and user (first and last name) for userid = 10, sessionid = 182
#
#
# ### 3. Give me every user name (first and last) in my music app history who listened to the song 'All Hands Against His Own'

# %%
# The table **sessions**, the **sessionId** column was used as a PARTITION KEY to filter the result by this column. We have used **itemInSession** column as clustering columns to sort the result.

query = "CREATE TABLE IF NOT EXISTS sessions"
query = query +"(sessionId int,itemInSession int,length float,artist text,song text, PRIMARY KEY(sessionId, itemInSession))"
try:
    session.execute(query)
except Exception as e:
    print(e)

# %%
# We have provided part of the code to set up the CSV file. Please complete the Apache Cassandra code below#
file = 'event_datafile_new.csv'

with open(file, encoding = 'utf8') as f:
    csvreader = csv.reader(f)
    next(csvreader) # skip header
    for line in csvreader:

        query = "INSERT INTO sessions (sessionId, itemInSession, length,artist,song)"
        query = query + "VALUES (%s,%s,%s,%s,%s)"

        session.execute(query, (int(line[8]),int(line[3]),float(line[5]),line[0],line[9]))

# %% [markdown]
# #### Do a SELECT to verify that the data have been inserted into each table

# %%
query= "SELECT artist,song,length FROM sessions WHERE sessionId=338 AND itemInSession=4"
try:
    rows = session.execute(query)
    print(rows)
except Exception as e:
    print(e)

for row in rows:
    print(row.artist,row.song,row.length)
# Out:
# <cassandra.cluster.ResultSet object at 0x7f82805c16a0>
# Faithless Music Matters (Mark Knight Dub) 495.30731201171875

# %% [markdown]
# ### COPY AND REPEAT THE ABOVE THREE CELLS FOR EACH OF THE THREE QUESTIONS

# %%
# The table **artist_song_user**, the **userid** and **sessionId** column was used as a PARTITION KEY to filter the result by this column. We have used **itemInSession** column as clustering columns to sort the result.

query = "CREATE TABLE IF NOT EXISTS artist_song_user"
query = query +"(userid int,sessionid int,artist text,song text,itemInSession int,firstName text,lastName text, PRIMARY KEY((userid,sessionId), itemInSession))"
try:
    session.execute(query)
except Exception as e:
    print(e)

# %%
file = 'event_datafile_new.csv'
with open(file, encoding = 'utf8') as f:
    csvreader = csv.reader(f)
    next(csvreader) # skip header
    for line in csvreader:

        query = "INSERT INTO artist_song_user (userid,sessionid,artist,song,itemInSession,firstName,lastName)"
        query = query + "VALUES (%s,%s,%s,%s,%s,%s,%s)"

        session.execute(query, (int(line[10]),int(line[8]),line[0],line[9],int(line[3]),line[1],line[4]))

# %%
        
query = "SELECT artist,song,firstName,lastName FROM artist_song_user WHERE userid=10 and sessionId=182"
try:
    artists = session.execute(query)

except Exception as e:
    print(e)

for artist in artists:
 
    print(artist.artist,artist.song,artist.firstname,artist.lastname)
# Out:
# Down To The Bone Keep On Keepin' On Sylvie Cruz
# Three Drives Greece 2000 Sylvie Cruz
# Sebastien Tellier Kilometer Sylvie Cruz
# Lonnie Gordon Catch You Baby (Steve Pitron & Max Sanna Radio Edit) Sylvie Cruz

# %%
# The table **user_song**, the **song**  column was used as a PARTITION KEY to filter the result by this column. We have used **user_id** column as clustering columns to sort the result.
query = "CREATE TABLE IF NOT EXISTS user_song"
query = query +"(song text,user_id int,firstname text,lastname text, PRIMARY KEY((song)), user_id))"
try:
    session.execute(query)
except Exception as e:
    print(e)

# %%
file = 'event_datafile_new.csv'
with open(file, encoding = 'utf8') as f:
    csvreader = csv.reader(f)
    next(csvreader) # skip header
    for line in csvreader:

        query = "INSERT INTO user_song (song ,user_id ,firstname ,lastname )"
        query = query + "VALUES (%s,%s,%s,%s)"

        session.execute(query, (line[9],int(line[10]),line[1],line[4]))

# %%
        
query = "SELECT firstname,lastname FROM user_song WHERE  song='All Hands Against His Own'"
try:
    songs = session.execute(query)
  
except Exception as e:
    print(e)

for song in songs:
 
    print(song.firstname,song.lastname)
# Out:
# Jacqueline Lynch
# Tegan Levine
# Sara Johnson

# %% [markdown]
# ### Drop the tables before closing out the sessions

# %%
query = "DROP TABLE sessions"
try:
    rows = session.execute(query)
except Exception as e:
    print(e)

query2 = "DROP TABLE artist_song_user"
try:
    rows = session.execute(query2)
except Exception as e:
    print(e)
    
query3 = "DROP TABLE user_song"
try:
    rows = session.execute(query3)
except Exception as e:
    print(e)

# %% [markdown]
# ### Close the session and cluster connection¶

# %%
session.shutdown()
cluster.shutdown()
